# %%
import pandas as pd
import yfinance as yf
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies', attrs = {'id': 'constituents'})

# %%
data = yf.download(" ".join(df[0]['Symbol']))
# Out:
# [*********************100%***********************]  505 of 505 completed
#
# 2 Failed downloads:
# - BRK.B: No data found, symbol may be delisted
# - BF.B: 1d data not available for startTime=-2208988800 and endTime=1634496300. Only 100 years worth of day granularity data are allowed to be fetched per request.

# %%
data['Adj Close']
# Out:
#                      A        AAL         AAP        AAPL        ABBV  \
# Date
# 1962-01-02         NaN        NaN         NaN         NaN         NaN
# 1962-01-03         NaN        NaN         NaN         NaN         NaN
# 1962-01-04         NaN        NaN         NaN         NaN         NaN
# 1962-01-05         NaN        NaN         NaN         NaN         NaN
# 1962-01-08         NaN        NaN         NaN         NaN         NaN
# ...                ...        ...         ...         ...         ...
# 2021-10-11  150.020004  20.129999  212.119995  142.809998  109.018311
# 2021-10-12  147.949997  20.290001  212.009995  141.509995  107.269516
# 2021-10-13  150.220001  19.610001  210.320007  140.910004  107.229996
# 2021-10-14  152.589996  19.639999  214.860001  143.759995  108.910004
# 2021-10-15  153.270004  19.980000  215.429993  144.839996  109.330002
#
#                    ABC        ABMD         ABT         ACN        ADBE  ...  \
# ...
